# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?q="

query = f"{url+city}&units=imperial&appid={weather_api_key}"

lat=[]
lon=[]
max_temp=[]
humidity=[]
clouds=[]
wind=[]
country=[]
date=[]
citiesit=[]

for city in cities:
    
    query = f"{url+city}&units=imperial&appid={weather_api_key}"
    
    print(f"Processing Record | {city}")
    
    response=requests.get(query).json()
    
    try:
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        clouds.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        citiesit.append(response["name"])
        
    except(KeyError):
        print("City not found, Skipping...")
        pass
    
print("-----------------")
print("Data Complete")
print("-----------------")
# Out:
# Processing Record | baykit
# Processing Record | rikitea
# Processing Record | tessalit
# Processing Record | albany
# Processing Record | chokurdakh
# Processing Record | hobart
# Processing Record | vao
# Processing Record | marcona
# City not found, Skipping...
# Processing Record | cape town
# Processing Record | ushuaia
# Processing Record | vila franca do campo
# Processing Record | carrickfergus
# Processing Record | ramotswa
# Processing Record | atuona
# Processing Record | narrabri
# Processing Record | dingle
# Processing Record | port moresby
# Processing Record | port alfred
# Processing Record | kruisfontein
# Processing Record | bluff
# Processing Record | sayat
# Processing Record | nago
# Processing Record | tigre
# Processing Record | ribeira grande
# Processing Record | mataura
# Processing Record | gondanglegi
# Processing Record | tygda
# Processing Record | nizhneyansk
# City not found, Skipping...
# Processing Record | livingstone
# Processing Record | tsihombe
# City not found, Skipping...
# Processing Record | taolanaro
# City not found, Skipping...
# Processing Record | egvekinot
# Processing Record | palmerston
# Processing Record | ucluelet
# Processing Record | souillac
# Processing Record | hermanus
# Processing Record | panjab
# Processing Record | busselton
# Processing Record | arraial do cabo
# Processing Record | eureka
# Processing Record | churapcha
# Processing Record | illoqqortoormiut
# City not found, Skipping...
# Processing Record | lisakovsk
# Processing Record | kodiak
# Processing Record | saint-philippe
# Processing Record | skibbereen
# Processing Record | torbay
# Processing Record | mount isa
# Processing Record | kingston
# Processing Record | jamestown
# Processing Record | lagoa
# Processing Record | paveh
# Processing Record | lasa
# Processing Record | barentsburg
# City not found, Skipping...
# Processing Record | guaraniacu
# Processing Record | pedernales
# Processing Record | upernavik
# Processing Record | acarau
# Processing Record | dwarka
# Processing Record | narsaq
# Processing Record | sao joao da barra
# Processing Record | hasaki
# Processing Record | rio do sul
# Processing Record | aklavik
# Processing Record | guerrero negro
# Processing Record | todos santos
# Processing Record | vaini
# Processing Record | williston
# Processing Record | bethel
# Processing Record | burica
# City not found, Skipping...
# Processing Record | punta arenas
# Processing Record | tasiilaq
# Processing Record | hilo
# Processing Record | beloha
# Processing Record | kapaa
# Processing Record | puerto narino
# Processing Record | isangel
# Processing Record | conceicao do araguaia
# Processing Record | chernyshevskiy
# Processing Record | vaitupu
# City not found, Skipping...
# Processing Record | carnarvon
# Processing Record | lebu
# Processing Record | chirawa
# Processing Record | bengkulu
# Processing Record | avarua
# Processing Record | talnakh
# Processing Record | chuy
# Processing Record | micheweni
# Processing Record | urdzhar
# City not found, Skipping...
# Processing Record | katsuura
# Processing Record | beihai
# Processing Record | poum
# Processing Record | ambrolauri
# Processing Record | boden
# Processing Record | mar del plata
# Processing Record | nauta
# Processing Record | uwayl
# City not found, Skipping...
# Processing Record | esperance
# Processing Record | geraldton
# Processing Record | sorsk
# Processing Record | camana
# Processing Record | westport
# Processing Record | port hedland
# Processing Record | port elizabeth
# Processing Record | hit
# Processing Record | sao miguel do araguaia
# Processing Record | rosetta
# Processing Record | barrow
# Processing Record | cacule
# Processing Record | amderma
# City not found, Skipping...
# Processing Record | tuktoyaktuk
# Processing Record | gizo
# Processing Record | airai
# Processing Record | karratha
# Processing Record | requena
# Processing Record | acambaro
# Processing Record | fortuna
# Processing Record | east london
# Processing Record | margate
# Processing Record | kumano
# Processing Record | byron bay
# Processing Record | vieste
# Processing Record | new norfolk
# Processing Record | quimper
# Processing Record | mount pleasant
# Processing Record | mys shmidta
# City not found, Skipping...
# Processing Record | caibarien
# Processing Record | taoudenni
# Processing Record | bredasdorp
# Processing Record | gravdal
# Processing Record | san patricio
# Processing Record | radhanpur
# Processing Record | ambilobe
# Processing Record | salalah
# Processing Record | misratah
# Processing Record | qaanaaq
# Processing Record | marsa matruh
# Processing Record | riyadh
# Processing Record | port-cartier
# Processing Record | hithadhoo
# Processing Record | wukari
# Processing Record | molina
# Processing Record | kahului
# Processing Record | ust-kamchatsk
# City not found, Skipping...
# Processing Record | bandarbeyla
# Processing Record | kavieng
# Processing Record | olafsvik
# Processing Record | totolapan
# Processing Record | broken hill
# Processing Record | dikson
# Processing Record | saleaula
# City not found, Skipping...
# Processing Record | praya
# Processing Record | ust-omchug
# Processing Record | daru
# Processing Record | puerto ayora
# Processing Record | luderitz
# Processing Record | leningradskiy
# Processing Record | port lincoln
# Processing Record | tlaxiaco
# City not found, Skipping...
# Processing Record | ostrovnoy
# Processing Record | yellowknife
# Processing Record | cairns
# Processing Record | rafaela
# Processing Record | clyde river
# Processing Record | norman wells
# Processing Record | victoria
# Processing Record | bambous virieux
# Processing Record | bayburt
# Processing Record | samusu
# City not found, Skipping...
# Processing Record | iskateley
# Processing Record | gejiu
# Processing Record | adeje
# Processing Record | mahebourg
# Processing Record | itarema
# Processing Record | naze
# Processing Record | leo
# Processing Record | cloquet
# Processing Record | yaan
# Processing Record | salym
# Processing Record | buala
# Processing Record | sijunjung
# Processing Record | havoysund
# Processing Record | ust-nera
# Processing Record | pevek
# Processing Record | goundam
# Processing Record | jumla
# Processing Record | severo-kurilsk
# Processing Record | khatanga
# Processing Record | vilyuysk
# Processing Record | lewistown
# Processing Record | kerchevskiy
# Processing Record | saskylakh
# Processing Record | sept-iles
# Processing Record | myitkyina
# Processing Record | birao
# Processing Record | okha
# Processing Record | kyra
# Processing Record | san lawrenz
# Processing Record | novyy urengoy
# Processing Record | lincoln
# Processing Record | dubbo
# Processing Record | barcelos
# Processing Record | hunfeld
# Processing Record | znamenskoye
# Processing Record | praia
# Processing Record | greece
# Processing Record | qarqin
# Processing Record | la primavera
# Processing Record | veraval
# Processing Record | bathsheba
# Processing Record | pacific grove
# Processing Record | arlit
# Processing Record | portland
# Processing Record | fairbanks
# Processing Record | cabedelo
# Processing Record | port pirie
# Processing Record | padang
# Processing Record | caravelas
# Processing Record | butaritari
# Processing Record | coquimbo
# Processing Record | mangaratiba
# Processing Record | saint-georges
# Processing Record | zaysan
# Processing Record | lokosovo
# Processing Record | road town
# Processing Record | neuquen
# Processing Record | laguna
# Processing Record | goba
# Processing Record | khovu-aksy
# Processing Record | nampula
# Processing Record | tarakan
# Processing Record | saint anthony
# Processing Record | port macquarie
# Processing Record | madras
# Processing Record | sentyabrskiy
# City not found, Skipping...
# Processing Record | ilulissat
# Processing Record | somerset
# Processing Record | jalu
# Processing Record | hofn
# Processing Record | samarai
# Processing Record | vila velha
# Processing Record | mastic beach
# Processing Record | kendari
# Processing Record | ciudad guayana
# Processing Record | labuhan
# Processing Record | vikarabad
# Processing Record | tawkar
# City not found, Skipping...
# Processing Record | san quintin
# Processing Record | mosquera
# Processing Record | wau
# Processing Record | namibe
# Processing Record | abu jubayhah
# City not found, Skipping...
# Processing Record | tasbuget
# City not found, Skipping...
# Processing Record | falealupo
# City not found, Skipping...
# Processing Record | elk city
# Processing Record | constitucion
# Processing Record | oksfjord
# Processing Record | laiagam
# City not found, Skipping...
# Processing Record | provideniya
# Processing Record | sorvag
# City not found, Skipping...
# Processing Record | elko
# Processing Record | puerto lopez
# Processing Record | ust-ilimsk
# Processing Record | mercedes
# Processing Record | urengoy
# Processing Record | foumban
# Processing Record | hay river
# Processing Record | grand river south east
# City not found, Skipping...
# Processing Record | pelotas
# Processing Record | kerema
# Processing Record | talaya
# Processing Record | tual
# Processing Record | komsomolskiy
# Processing Record | inirida
# Processing Record | kalmunai
# Processing Record | lata
# Processing Record | ponta do sol
# Processing Record | belushya guba
# City not found, Skipping...
# Processing Record | kungurtug
# Processing Record | alyangula
# Processing Record | musoma
# Processing Record | malwan
# City not found, Skipping...
# Processing Record | uchiza
# Processing Record | bilma
# Processing Record | ekhabi
# Processing Record | tambura
# Processing Record | burhaniye
# Processing Record | thompson
# Processing Record | macapa
# Processing Record | marrakesh
# Processing Record | cordele
# Processing Record | saldanha
# Processing Record | uhlove
# Processing Record | castro
# Processing Record | guiglo
# Processing Record | cabo san lucas
# Processing Record | port augusta
# Processing Record | igrim
# Processing Record | puerto ayacucho
# Processing Record | vardo
# Processing Record | kachikau
# City not found, Skipping...
# Processing Record | axim
# Processing Record | chekhov
# Processing Record | henties bay
# Processing Record | ginda
# Processing Record | hualmay
# Processing Record | barawe
# City not found, Skipping...
# Processing Record | yatou
# Processing Record | fayaoue
# Processing Record | shache
# Processing Record | ahipara
# Processing Record | karaul
# City not found, Skipping...
# Processing Record | meulaboh
# Processing Record | ketchikan
# Processing Record | carthage
# Processing Record | villanueva
# Processing Record | sauda
# Processing Record | terracina
# Processing Record | banjar
# Processing Record | amapa
# Processing Record | nautla
# Processing Record | teya
# Processing Record | codrington
# Processing Record | petropavlovsk-kamchatskiy
# Processing Record | georgetown
# Processing Record | palmer
# Processing Record | dickinson
# Processing Record | lompoc
# Processing Record | harper
# Processing Record | hurghada
# Processing Record | mecca
# Processing Record | shakawe
# Processing Record | karkaralinsk
# City not found, Skipping...
# Processing Record | klaksvik
# Processing Record | pundaguitan
# Processing Record | landerneau
# Processing Record | flin flon
# Processing Record | pangai
# Processing Record | roald
# Processing Record | nuuk
# Processing Record | uruzgan
# Processing Record | aykhal
# Processing Record | waseca
# Processing Record | vostok
# Processing Record | bonthe
# Processing Record | marsh harbour
# Processing Record | longyearbyen
# Processing Record | christchurch
# Processing Record | bara
# Processing Record | lethem
# Processing Record | tuggurt
# City not found, Skipping...
# Processing Record | tuatapere
# Processing Record | cuenca
# Processing Record | jinchang
# Processing Record | san luis
# Processing Record | saint george
# Processing Record | debre birhan
# Processing Record | atar
# Processing Record | tumannyy
# City not found, Skipping...
# Processing Record | nome
# Processing Record | sterling
# Processing Record | lac du bonnet
# Processing Record | erenhot
# Processing Record | faya
# Processing Record | necochea
# Processing Record | povarovo
# Processing Record | attawapiskat
# City not found, Skipping...
# Processing Record | the pas
# Processing Record | umzimvubu
# City not found, Skipping...
# Processing Record | srednekolymsk
# Processing Record | okato
# Processing Record | el faiyum
# City not found, Skipping...
# Processing Record | mugla
# Processing Record | umm lajj
# Processing Record | moose factory
# Processing Record | tres arroyos
# Processing Record | kaitangata
# Processing Record | alofi
# Processing Record | mount gambier
# Processing Record | sumy
# Processing Record | port hardy
# Processing Record | evensk
# Processing Record | mesetas
# Processing Record | chifeng
# Processing Record | samarinda
# Processing Record | ternate
# Processing Record | nikolskoye
# Processing Record | huarmey
# Processing Record | acapulco
# Processing Record | oktyabrskiy
# Processing Record | shakiso
# Processing Record | santa cruz
# Processing Record | conceicao da barra
# Processing Record | kupino
# Processing Record | snezhnogorsk
# Processing Record | araguatins
# City not found, Skipping...
# Processing Record | paradwip
# City not found, Skipping...
# Processing Record | souris
# Processing Record | nishihara
# Processing Record | nazareno
# Processing Record | gamboma
# Processing Record | nieuw amsterdam
# Processing Record | basqal
# Processing Record | mnogovershinnyy
# Processing Record | raymond
# Processing Record | sao joaquim da barra
# Processing Record | omboue
# Processing Record | tezu
# Processing Record | goderich
# Processing Record | usinsk
# Processing Record | capoterra
# Processing Record | ogulin
# Processing Record | martapura
# Processing Record | coahuayana
# Processing Record | taburi
# City not found, Skipping...
# Processing Record | sikonge
# Processing Record | porto belo
# Processing Record | nevers
# Processing Record | witu
# Processing Record | norden
# Processing Record | maarianhamina
# Processing Record | luganville
# Processing Record | turukhansk
# Processing Record | athabasca
# Processing Record | novo aripuana
# Processing Record | moron
# Processing Record | cherskiy
# Processing Record | meyungs
# City not found, Skipping...
# Processing Record | umm kaddadah
# Processing Record | san jose del palmar
# Processing Record | isla vista
# Processing Record | khani
# Processing Record | brae
# Processing Record | mahajanga
# Processing Record | paracatu
# Processing Record | cuervos
# Processing Record | buraydah
# Processing Record | luorong
# Processing Record | craig
# Processing Record | lakatoro
# Processing Record | danville
# Processing Record | butterworth
# Processing Record | zemio
# Processing Record | tabiauea
# City not found, Skipping...
# Processing Record | araouane
# Processing Record | stolin
# Processing Record | rocha
# Processing Record | lorengau
# Processing Record | champerico
# Processing Record | ola
# Processing Record | salinopolis
# Processing Record | lahad datu
# Processing Record | cockburn harbour
# City not found, Skipping...
# Processing Record | maltahohe
# Processing Record | bubaque
# Processing Record | sao gotardo
# Processing Record | invermere
# Processing Record | manacapuru
# Processing Record | kavaratti
# Processing Record | boa vista
# Processing Record | tilichiki
# Processing Record | rawatsar
# Processing Record | kidal
# Processing Record | doctor pedro p. pena
# City not found, Skipping...
# Processing Record | state college
# Processing Record | half moon bay
# Processing Record | solnechnogorsk
# Processing Record | vicuna
# Processing Record | anchorage
# Processing Record | casas adobes
# Processing Record | west odessa
# Processing Record | viedma
# Processing Record | tibati
# Processing Record | sabang
# Processing Record | iqaluit
# Processing Record | tabas
# Processing Record | kushima
# Processing Record | beringovskiy
# Processing Record | jepelacio
# Processing Record | soyo
# Processing Record | kutum
# Processing Record | sibolga
# Processing Record | alberton
# Processing Record | saint-augustin
# Processing Record | salinas
# Processing Record | khor
# Processing Record | touros
# Processing Record | cidreira
# Processing Record | rajauri
# Processing Record | cayenne
# Processing Record | hambantota
# Processing Record | ngunguru
# Processing Record | kaiyuan
# Processing Record | sulangan
# Processing Record | kostolac
# Processing Record | xanxere
# Processing Record | tadine
# Processing Record | gisborne
# Processing Record | hamilton
# Processing Record | ginir
# Processing Record | santo domingo
# Processing Record | inyonga
# Processing Record | muravlenko
# Processing Record | kununurra
# Processing Record | tigil
# Processing Record | machado
# Processing Record | ewa beach
# Processing Record | palencia
# Processing Record | bishop auckland
# Processing Record | saint-pierre
# Processing Record | hohhot
# Processing Record | blagoyevo
# Processing Record | pouembout
# Processing Record | te anau
# Processing Record | los llanos de aridane
# Processing Record | port blair
# Processing Record | hovd
# Processing Record | xai-xai
# Processing Record | sola
# Processing Record | sao raimundo nonato
# Processing Record | batagay-alyta
# Processing Record | skjervoy
# Processing Record | alice springs
# Processing Record | muros
# Processing Record | yauya
# Processing Record | phangnga
# Processing Record | north platte
# Processing Record | kachiry
# Processing Record | balagansk
# Processing Record | sambava
# Processing Record | dandong
# Processing Record | paamiut
# Processing Record | lugoba
# Processing Record | pangnirtung
# Processing Record | alytus
# Processing Record | tiksi
# Processing Record | lavrentiya
# Processing Record | tura
# Processing Record | pimenta bueno
# Processing Record | mayahi
# Processing Record | makakilo city
# Processing Record | pitimbu
# Processing Record | itoman
# Processing Record | santa maria
# Processing Record | rawson
# Processing Record | sepuka
# Processing Record | oranjemund
# Processing Record | capao da canoa
# Processing Record | sobolevo
# Processing Record | saint-joseph
# Processing Record | midland
# Processing Record | verkhnevilyuysk
# Processing Record | dubti
# Processing Record | kudahuvadhoo
# Processing Record | mae hong son
# Processing Record | xam nua
# Processing Record | marawi
# Processing Record | polis
# Processing Record | port-gentil
# Processing Record | londoko
# Processing Record | adre
# Processing Record | comodoro rivadavia
# Processing Record | san juan
# Processing Record | faanui
# Processing Record | etropole
# Processing Record | honiara
# Processing Record | andevoranto
# City not found, Skipping...
# Processing Record | kulhudhuffushi
# Processing Record | volchansk
# Processing Record | toguchin
# Processing Record | bur gabo
# City not found, Skipping...
# Processing Record | grindavik
# Processing Record | yinchuan
# Processing Record | urumqi
# Processing Record | surskoye
# Processing Record | inhambane
# Processing Record | montrose
# Processing Record | itacarambi
# Processing Record | sioux lookout
# Processing Record | sao filipe
# Processing Record | ruwi
# Processing Record | hartselle
# Processing Record | merauke
# Processing Record | valleyview
# Processing Record | wanaka
# Processing Record | kuhestan
# City not found, Skipping...
# Processing Record | santo antonio do sudoeste
# Processing Record | sitka
# Processing Record | gorontalo
# Processing Record | camocim
# Processing Record | poopo
# Processing Record | aswan
# Processing Record | ardesen
# Processing Record | kamenskoye
# City not found, Skipping...
# Processing Record | leh
# Processing Record | terra nova
# Processing Record | iglesias
# Processing Record | darhan
# -----------------
# Data Complete
# -----------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
columns = ["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]
series = [citiesit, lat, lon, max_temp, humidity, clouds, wind, country, date]

dict = {"City":citiesit, "Lat":lat, "Lng":lon, "Max Temp":max_temp, "Humidity":humidity, 
        "Cloudiness":clouds, "Wind Speed":wind, "Country":country, "Date":date}

city_data = pd.DataFrame(dict)
city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Baykit  61.6700   96.3700     15.49        94         100        4.36
# 1     Rikitea -23.1203 -134.9692     77.49        67          73        6.33
# 2    Tessalit  20.1986    1.0114     85.82        19          87        9.78
# 3      Albany  42.6001  -73.9662     48.20        66         100        5.64
# 4  Chokurdakh  70.6333  147.9167     15.26        88         100        5.17
#
#   Country        Date
# 0      RU  1618701349
# 1      PF  1618701698
# 2      ML  1618701220
# 3      US  1618701234
# 4      RU  1618701245

# %%
city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean    18.485676   15.753708   58.756793   69.686594   55.572464    7.887355
# std     33.446091   91.570625   21.133184   22.376127   38.422598    4.864718
# min    -54.800000 -179.166700  -23.550000    5.000000    0.000000    0.450000
# 25%     -8.940775  -63.391375   46.250000   59.000000   19.750000    4.202500
# 50%     21.331250   19.584650   62.815000   74.000000   73.000000    6.910000
# 75%     46.841775   96.217525   76.480000   87.000000   91.000000   11.300000
# max     78.218600  179.316700   92.080000  100.000000  100.000000   27.630000
#
#                Date
# count  5.520000e+02
# mean   1.618702e+09
# std    2.634843e+02
# min    1.618701e+09
# 25%    1.618701e+09
# 50%    1.618702e+09
# 75%    1.618702e+09
# max    1.618702e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
indexnames = city_data[city_data["Humidity"]>100].index
indexnames
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_data.drop(indexnames)
clean_city_data
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Baykit  61.6700   96.3700     15.49        94         100
# 1       Rikitea -23.1203 -134.9692     77.49        67          73
# 2      Tessalit  20.1986    1.0114     85.82        19          87
# 3        Albany  42.6001  -73.9662     48.20        66         100
# 4    Chokurdakh  70.6333  147.9167     15.26        88         100
# ..          ...      ...       ...       ...       ...         ...
# 547     Ardeşen  41.1911   40.9875     59.00        67          75
# 548         Leh  34.1667   77.5833     35.08        83          99
# 549  Terra Nova -12.3667  -40.6667     77.00        65           0
# 550    Iglesias  39.3114    8.5350     46.00        87          20
# 551      Darhan  49.4867  105.9228     35.83        55          42
#
#      Wind Speed Country        Date
# 0          4.36      RU  1618701349
# 1          6.33      PF  1618701698
# 2          9.78      ML  1618701220
# 3          5.64      US  1618701234
# 4          5.17      RU  1618701245
# ..          ...     ...         ...
# 547        5.75      TR  1618701967
# 548        5.88      IN  1618701967
# 549        9.22      BR  1618701968
# 550        2.30      IT  1618701968
# 551       15.82      MN  1618701969
#
# [552 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lat, max_temp, marker='o', color='royalblue', edgecolors='black')
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humidity, marker='o', color='royalblue', edgecolors='black')
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, clouds, marker='o', color='royalblue', edgecolors='black')
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind, marker='o', color='royalblue', edgecolors='black')
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Linear Regression

# %%
indexnamesn = clean_city_data[clean_city_data["Lat"]>=0].index
indexnamess = clean_city_data[clean_city_data["Lat"]<0].index

n_hem = pd.DataFrame(clean_city_data)
n_hem = n_hem.drop(indexnamess) 
s_hem = pd.DataFrame(clean_city_data)
s_hem = s_hem.drop(indexnamesn)
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 1                      Rikitea -23.1203 -134.9692     77.49        67
# 5                       Hobart -42.8794  147.3294     57.92        58
# 6                          Vao -22.6667  167.4833     75.34        74
# 7                    Cape Town -33.9258   18.4232     60.89        88
# 8                      Ushuaia -54.8000  -68.3000     53.60        54
# ..                         ...      ...       ...       ...       ...
# 540                     Wanaka -44.7000  169.1500     50.11        81
# 541  Santo Antônio do Sudoeste -26.0736  -53.7253     66.96        74
# 544                    Camocim  -2.9022  -40.8411     77.70        88
# 545                      Poopó -18.3667  -66.9667     52.07        26
# 549                 Terra Nova -12.3667  -40.6667     77.00        65
#
#      Cloudiness  Wind Speed Country        Date
# 1            73        6.33      PF  1618701698
# 5            75       11.50      AU  1618701254
# 6            33       18.34      NC  1618701699
# 7             0        4.61      ZA  1618701300
# 8            40       10.36      AR  1618701144
# ..          ...         ...     ...         ...
# 540          96        7.16      NZ  1618701961
# 541          57        4.94      BR  1618701962
# 544          16       12.28      BR  1618701964
# 545           0        4.38      BO  1618701965
# 549           0        9.22      BR  1618701968
#
# [183 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = n_hem['Lat']
y = n_hem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7345315418706394

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = s_hem['Lat']
y = s_hem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.45137918077506056

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = n_hem['Lat']
y = n_hem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.022978265959184004

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = s_hem['Lat']
y = s_hem['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.06137531075868197

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = n_hem['Lat']
y = n_hem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.004165190829371711

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = s_hem['Lat']
y = s_hem['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.007422096466312046

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = n_hem['Lat']
y = n_hem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.012011230167577637

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = s_hem['Lat']
y = s_hem['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x, y)
plt.plot(x,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0003121109121125647
